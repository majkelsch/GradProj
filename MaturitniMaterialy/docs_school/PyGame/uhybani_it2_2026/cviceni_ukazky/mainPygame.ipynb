# %% [markdown]
# # Základní aplikace

# %%
import pygame #zavolání knihovny
  
pygame.init() #inicializace knihovny 
  
# CREATING CANVAS 
screen = pygame.display.set_mode((500, 500)) # VELIKOST OKNA
  
# TITLE OF CANVAS 
pygame.display.set_caption("My Board") # NÁZEV OKNA
running = True #POKUD JE True, TAK SE BUDE VYKONÁVAT SMYČKA
  
while running: 
    for event in pygame.event.get(): #vyprazdňuje eventy
        if event.type == pygame.QUIT:  #POKUD dáme křížek, TAK SE UKONČÍ SMYČKA
            running = False
    pygame.display.update() #OBNOVENÍ OBRAZOVKY
pygame.quit() #UKONČENÍ PYGAME

# %% [markdown]
# # Vložení obrázku

# %%
import pygame 
  
pygame.init() 
  
color = (255,255,255) # WHITE color
  
# CREATING CANVAS 
screen = pygame.display.set_mode((500,500)) # VELIKOST OKNA
x, y = screen.get_size() # zjistí velikost okna
screen = pygame.display.set_mode((500, 500), pygame.RESIZABLE) # okno se dá zvětšit/ změnšit při běhu programu
  
# TITLE OF CANVAS 
pygame.display.set_caption("Show Image") # NÁZEV OKNA
  
image = pygame.image.load("obr.jpeg") # NAČTENÍ OBRÁZKU
running = True
  
while running: 
    screen.fill(color) 
    screen.blit(image, dest = (100, 100)) # VLOŽENÍ OBRÁZKU na určitou pozici (vloží se levý horní roh na tuto souřadnici) 
  
    for event in pygame.event.get(): 
        if event.type == pygame.QUIT: 
            running = False
  
    pygame.display.update()
pygame.quit()

# %% [markdown]
# # Vložení tvarů

# %%
# Importing pygame module
import pygame
from pygame.locals import * # nemusím psát pygame.locals.k_escape, ale jen k_escape protože jsem si importvoal všechny tlačítka

# initiate pygame and give permission
# to use pygame's functionality.
pygame.init()
running= True
clock = pygame.time.Clock() # FPS
while running:
    clock.tick(1) # kolikrát za vteřinu toto udělám
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    # create the display surface object
    # of specific dimension.
    window = pygame.display.set_mode((600, 600))

    # Fill the scree with white color
    window.fill((255, 255, 255))

    #                           barva  pozice poice leveho rohu sirka vyska   tloustka
    pygame.draw.rect(window, (0, 0, 255), [50, 500, 100, 50], 2)
    pygame.draw.rect(window, (0, 0, 255), [170, 500, 100, 50], 2,4,3,2) # více rohu zaoblenych
    pygame.draw.rect(window, (0, 0, 255), [50, 400, 100, 50], 0)
    pygame.draw.rect(window, (0, 0, 255), [170, 400, 100, 50], 0) # zaobleny roh
    #                            barva     pozice   polomer tloustka
    pygame.draw.circle(window, (0, 255, 0),[50, 300], 20, 2)
    pygame.draw.circle(window, (0, 255, 0),[50, 200], 20, 0)
    #                                             a           b          c  tloustka
    pygame.draw.polygon(window, (255, 0, 0), [[100, 300], [150, 300],[125, 250]],0)
    pygame.draw.polygon(window, (255, 0, 0), [[100, 200], [150, 200],[125, 250]],2)
    #                            barva     pozice   pozice  tloustka
    pygame.draw.line(window, (0, 0, 0), [30, 150],  [150, 150], 5)
    #                            barva     a         b          c             d        e
    pygame.draw.polygon(window, "blue", [(100, 30), (50, 80), (65, 130), (135, 130), (150,80)]) 
    pygame.display.update()
pygame.quit()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.12.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Změna barvy pozadí, title, ikony

# %%
# Importing the library
import pygame
 
# Initializing Pygame modules
pygame.init()
 
# Initializing surface
surface = pygame.display.set_mode((400, 300))
pygame.display.set_caption('GeeksforGeeks') # NÁZEV OKNA
 
# Here we load the image we want to use
Icon = pygame.image.load('obr.jpeg')
 
# We use set_icon to set new icon
pygame.display.set_icon(Icon)
running = True
# Initializing RGB Color
color = (0, 0, 255)
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    # Changing surface color
    surface.fill(color)
    pygame.display.flip()
# Changing surface color
pygame.quit()

# %% [markdown]
# # Surface
# Prakticky vše má nějaký povrch, ať už tedy naše hlavní pozadí, tak nějaký námi vytvořený objekt, například obdelník, kruh atd.
# Všemu tomuto můžeme měnit jeho povrch (čili barvu, tapetu, fólii)

# %%
# Importing the library
import pygame
 
# Initializing Pygame modules
pygame.init()
 
# Initializing surface
screen = pygame.display.set_mode((400, 300))
pygame.display.set_caption('GeeksforGeeks') # NÁZEV OKNA
 
# Here we load the image we want to use
Icon = pygame.image.load('obr.jpeg')
 
# We use set_icon to set new icon
pygame.display.set_icon(Icon)
running = True
# Initializing RGB Color
color = (0, 0, 255)
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    # Changing surface color
 
# putting our image surface on display 
# surface
    pygame.draw.circle(screen, (0, 255, 0),[100, 100], 50, 2)
    screen.blit(Icon,(100,100)) # pozice obrázku
    pygame.display.flip()
# Changing surface color
pygame.quit()

# %% [markdown]
# # Vložení obrázku a prolnutí pozadí (transparentní pozadí / odstranění pozadí z obrázku)

# %%
import pygame #zavolání knihovny
  
pygame.init() #inicializace knihovny 
  
screen = pygame.display.set_mode((1920, 1080)) # VELIKOST OKNA
screen.fill((0, 0, 0))  # Nastavení černého pozadí
pygame.display.set_caption("My Board") # NÁZEV OKNA
running = True #POKUD JE True, TAK SE BUDE VYKONÁVAT SMYČKA
  
while running: 
    for event in pygame.event.get(): #vyprazdňuje eventy
        if event.type == pygame.QUIT:  #POKUD dáme křížek, TAK SE UKONČÍ SMYČKA
            running = False

    image = pygame.image.load('gfg.png')  # NAČTENÍ OBRÁZKU
    #image = pygame.image.load('gfgnp.png')  # NAČTENÍ OBRÁZKU bez pozadí (možná lepší --> nemusíte dělat copy atd.) nutno jiný SW pro odstranění pozadí
    
    # Získání kopie obrázku
    transparent_image = image.copy() # Získání kopie obrázku --> nechceme přepisovat původní data. Vytvoří v paměti nový odkaz se stejnými daty
    
    # Nastavení průhledného pozadí
    transparent_image.set_colorkey((255, 255, 255))  # Nastavení bílé barvy jako průhledné pro námi zvolený zkopírovaný obrázek (je potřeba aby obrázek byl skutečně bílý)

    screen.blit(transparent_image, (100, 100))

    pygame.display.update()
pygame.quit() #UKONČENÍ PYGAME

# %% [markdown]
# # Práce s časem

# %%
import pygame #zavolání knihovny
  
pygame.init() #inicializace knihovny 
  
screen = pygame.display.set_mode((1920, 1080)) # VELIKOST OKNA
screen.fill((0, 0, 0))  # Nastavení černého pozadí
pygame.display.set_caption("My Board") # NÁZEV OKNA
running = True #POKUD JE True, TAK SE BUDE VYKONÁVAT SMYČKA
  

clock=pygame.time.Clock() # FPS (kolikrát za vteřinu toto udělám) vlastně objekt, který mám vytvořený pro trackování času


while running: 
    clock.tick(1) # kolikrát za vteřinu toto udělám
    print(clock.get_time())
    for event in pygame.event.get(): #vyprazdňuje eventy
        if event.type == pygame.QUIT:  #POKUD dáme křížek, TAK SE UKONČÍ SMYČKA
            pygame.time.wait(5000) # čeká 5 sekund
            # making the script wait for 5000 seconds
            pygame.time.delay(5000) # čeká 5 sekund, ale využívá procesor (je přesnější)
            running = False
    ticks=pygame.time.get_ticks() # získání čas od spuštění programu
    print(ticks)
    image = pygame.image.load('gfg.png')  # NAČTENÍ OBRÁZKU
    screen.blit(transparent_image, (100, 100))

    pygame.display.update()
pygame.quit() #UKONČENÍ PYGAME

# %% [markdown]
# # Jednoduchá aplikace, když kliknete přičte se čas

# %%
import pygame
import sys

pygame.init()

# Nastavení obrazovky
screen = pygame.display.set_mode((800, 600))
pygame.display.set_caption("Bomb Timer")

# Barvy
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

# Font
font = pygame.font.Font(None, 36)

# Čas pro zneškodnění bomby (v milisekundách)
BOMB_TIMER = 10000  # 10 sekund
TIME_BONUS = 5000   # 5 sekund

def main():
    clock.tick(1) # kolikrát za vteřinu toto udělám (znamená, že čas se mi bude posouvat o 1 sekundu -> znamená, že odpočet prodloužím když kliknu,
    # ale když kliknu v 0.5 vteřině, bomba bouchne za 0.9 sekundy tak bomba bouchne, jelikož se mi nestihne zkontrolovat kliknutí, které proběhne o 0,5 později než můj klik
    start_time = pygame.time.get_ticks()

    running = True
    bonus_applied = False  # Indikátor, zda byl bonus již přidán
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
                pygame.quit()
                sys.exit()

            if event.type == pygame.MOUSEBUTTONDOWN:
                # Pokud uživatel kliknul na tlačítko a bonus ještě nebyl přidán
                start_time += TIME_BONUS  # Přičtení bonusu k začátkovému času

        current_time = pygame.time.get_ticks()  # Aktuální čas
        remaining_time = max(0, BOMB_TIMER - (current_time - start_time))  # Výpočet zbývajícího času

        screen.fill(BLACK)  # Vyplníme obrazovku černou barvou

        # Zobrazení zbývajícího času na obrazovce
        text = font.render(f"Zbývající čas: {remaining_time // 1000} s", True, WHITE)
        screen.blit(text, (200, 250))

        pygame.display.flip()

        # Omezení rychlosti smyčky
        pygame.time.Clock().tick(30)

if __name__ == "__main__":
    main()
    pygame.quit()

# %% [markdown]
# # Vykreslení objektů pomocí kliku

# %% [markdown]
# Kruh

# %%
import pygame
from pygame.locals import *

pygame.init()

window = pygame.display.set_mode((600, 600))

window.fill((255, 255, 255))

circle_positions = []
circle_radius = 60
color = (0, 0, 255)

run = True
while run:
	for event in pygame.event.get():
		if event.type == QUIT:
			run = False
			
		elif event.type == MOUSEBUTTONDOWN:
			position = event.pos
			circle_positions.append(position)
		
	for position in circle_positions:
		pygame.draw.circle(window, color, position,
						circle_radius)
	pygame.display.update()
pygame.quit()

# %% [markdown]
# Čtverec

# %%
import pygame
from pygame.locals import *

pygame.init()

window = pygame.display.set_mode((600, 600))

window.fill((255, 255, 255))

circle_positions = []
circle_radius = 60
color = (0, 0, 255)

run = True
while run:
    for event in pygame.event.get():
        if event.type == QUIT:
            run = False
            
        elif event.type == MOUSEBUTTONDOWN:
            position = event.pos #pygame.mouse.get_pos()
            circle_positions.append(position)
    
    if len(circle_positions) % 4 == 0:
        for i in range(0,len(circle_positions),4):
            pygame.draw.polygon(window, (255, 0, 0), [circle_positions[i], circle_positions[i+1],circle_positions[i+2],circle_positions[i+3]],0)
        pygame.display.update()
pygame.quit()

# %% [markdown]
# # Animace

# %%
import pygame

pygame.init()
clock = pygame.time.Clock() # pro FPS
screen = pygame.display.set_mode((400, 600))

running = True
color = (255, 0, 0)
a = 50
b = 200 # vykreslím a už neměním (statické části)
vlevo = False

while running: # vše co je zde měním dynamicky dle ticku
    clock.tick(60) # FPS
    screen.fill((0, 0, 0))
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    #                            barva     pozice   polomer
    pygame.draw.circle(screen, (255, 255, 255), (a, b), 20) 
    pygame.draw.line(screen, (255, 102, 0), [25, 220],  [370, 220], 5)
    if vlevo == False and a >350:
        vlevo = True
    elif vlevo and a < 45:
        vlevo = False
    if vlevo:
        a -= 1
    else:
        a += 1                
    
    pygame.display.update()

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Obrazek a rotace

# %%
import pygame

pygame.init()
clock = pygame.time.Clock()  # pro FPS
screen = pygame.display.set_mode((400, 600))

running = True
a = 50
b = 200  # vykreslím a už neměním (statické části)
vlevo = False
ball = pygame.image.load('ball_image.png')  # NAČTENÍ OBRÁZKU
ball = pygame.transform.scale(ball, (40, 40))  # menim velikost obrazku
rotation_angle = 0
while running:  # vše co je zde měním dynamicky dle ticku
    clock.tick(60)  # FPS
    screen.fill((0, 0, 0))
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    # Rotate the ball image
    rotated_ball = pygame.transform.rotate(ball, rotation_angle)
    ball_rect = rotated_ball.get_rect(center=(a, b))

    screen.blit(rotated_ball, ball_rect)  # vykreslení rotovaného obrázku
    pygame.draw.line(screen, (255, 102, 0), [25, b+20], [370, b+20], 5)

    if vlevo:
        a -= 1
        rotation_angle += 15  # Rotate clockwise 
        if a <= 50:
            vlevo = False
    else:
        a += 1
        rotation_angle -= 15  # Rotate counterclockwise
        if a >= 350:
            vlevo = True

    pygame.display.update()

pygame.quit()

# %% [markdown]
# # Práce s textem

# %%
# import pygame
import pygame

# initializing pygame
pygame.font.init()

# check whether font is initialized
# or not
pygame.font.get_init()

# create the display surface
display_surface = pygame.display.set_mode((500, 500))

# change the window screen title
pygame.display.set_caption('Our Text')

# Create a font file by passing font file
# and size of the font
font1 = pygame.font.SysFont('freesanbold.ttf', 50)
font2 = pygame.font.SysFont('chalkduster.ttf', 40)

# Render the texts that you want to display
text1 = font1.render('GeeksForGeeks', True, (0, 255, 0))
text2 = font2.render('GeeksForGeeks', True, (0, 255, 0))

# create a rectangular object for the
# text surface object
textRect1 = text1.get_rect()
textRect2 = text2.get_rect()

# setting center for the first text
textRect1.center = (250, 300)

# setting center for the second text
textRect2.center = (250, 300)

while True:

	# add background color using RGB values
	display_surface.fill((255, 0, 0))
	display_surface.blit(text1, (0,0)) # vložím né podle centru ale prostě na pozici 0 0 což je levý horní roh
	display_surface.blit(text2, textRect2)

	for event in pygame.event.get():
		if event.type == pygame.QUIT:
			pygame.quit()
			quit()
		pygame.display.update()

# %%
# import pygame module
import pygame

# import sys library
import sys

# initializing pygame
pygame.init()

clock = pygame.time.Clock()

# Set the window screen size
display_screen = pygame.display.set_mode((500, 500))

# add font style and size
base_font = pygame.font.Font(None, 40)


# stores text taken by keyboard
user_text = ''

# set left, top, width, height in 
# Pygame.Rect()
input_rect = pygame.Rect(200, 200, 140, 32)
color_active = pygame.Color("lightskyblue")
color_passive = pygame.Color("gray15")
color = color_passive

active = False

while True:
	
	for event in pygame.event.get():
		if event.type == pygame.QUIT:
			pygame.quit()
			sys.exit()

		# when mouse collides with the rectangle
		# make active as true
		if event.type == pygame.MOUSEBUTTONDOWN:
			if input_rect.collidepoint(event.pos):
				active = True

		# if the key is physically pressed down
		if event.type == pygame.KEYDOWN:
			if event.key == pygame.K_BACKSPACE:
				
				# stores text except last letter
				user_text = user_text[0:-1]
			else:
				user_text += event.unicode

	display_screen.fill((0, 0, 0))

	if active:
		color = color_active
	else:
		color = color_passive

	pygame.draw.rect(display_screen, color, input_rect)
	
	# render the text
	text_surface = base_font.render(user_text, True, (255, 255, 255))
	display_screen.blit(text_surface, (input_rect.x + 5, input_rect.y + 5))
	input_rect.w = max(100, text_surface.get_width() + 10)
	pygame.display.flip()
	clock.tick(60)

# %% [markdown]
# # Bomba čas a klik

# %%
import pygame
import sys
pygame.init()
clock = pygame.time.Clock()
screen = pygame.display.set_mode((500, 500))
base_font = pygame.font.Font(None, 40)
bomb_timer = 5  # seconds
text = 'Bomba vybuchne za: {}'.format(bomb_timer)
bomb_timer_text = base_font.render(text, True, (0, 0, 0))
bomb_timer_text_rect = bomb_timer_text.get_rect(center=(250, 250))
active = False
running = True
while running: 
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit() # quit pygame
            sys.exit() # exit the program
        if event.type == pygame.MOUSEBUTTONDOWN:
            bomb_timer += 5
    screen.fill((255, 255, 255)) # fill the screen with white color
    # time in seconds until the bomb explodes on two decimal
    text = 'Bomba vybuchne za: {:.2f}'.format(bomb_timer)       
    bomb_timer_text = base_font.render(text, True, (0, 0, 0))
    screen.blit(bomb_timer_text, bomb_timer_text_rect) # display the text on the screen
    bomb_timer -= 1/60
    if bomb_timer < 0:
        running = False
    pygame.display.flip()
    clock.tick(60)

# %% [markdown]
# # Skakani

# %%
# import pygame module in this program 
import pygame
 
# activate the pygame library . 
# initiate pygame and give permission 
# to use pygame's functionality. 
pygame.init()
 
# create the display surface object 
# of specific dimension..e(500, 500). 
screen = pygame.display.set_mode((500, 500))
 
# set the pygame screendow name 
pygame.display.set_caption("Jump Game")
 
# object current co-ordinates
x = 200
y = 200
 
# dimensions of the object
width = 30
height = 40
 
# Stores if player is jumping or not
isjump = False
 
# Force (v) up and mass m.
v = 7
m = 1
 
# Indicates pygame is running
run = True
ctverec = pygame.Rect(x, y, width, height)
cara1_rect = pygame.Rect(0, 200+height, 250, 2)
cara2_rect = pygame.Rect(350, 200+height*3, 150, 2)
# infinite loop
while run:
 
    # completely fill the surface object 
    # with black colour 
    screen.fill((0, 0, 0))
 
    # drascreeng object on screen which is rectangle here 

    pygame.draw.rect(screen, (255, 0, 0), ctverec)

    # Draw obstacles
    pygame.draw.rect(screen, (255, 255, 0), cara1_rect)
    pygame.draw.rect(screen, (255, 255, 0), cara2_rect)
    # iterate over the list of Event objects 
    # that was returned by pygame.event.get() method. 
    for event in pygame.event.get():
         
        # if event object type is QUIT 
        # then quitting the pygame 
        # and program both. 
        if event.type == pygame.QUIT:
             
            # it will make exit the while loop
            run = False
    # stores keys pressed
    keys = pygame.key.get_pressed() 
    if keys[pygame.K_a]:
        ctverec.x -= 5
    if keys[pygame.K_d]:
        ctverec.x += 5
 
        # if space bar is pressed
    if keys[pygame.K_SPACE]:
            
        # make isjump equal to True
        isjump = True
            
    if isjump :
        # calculate force (F). F = 1 / 2 * mass * velocity ^ 2.
        F =(1 / 2)*m*(v**2)
         
        # change in the y co-ordinate
        ctverec.y -= F
         
        # decreasing velocity while going up and become negative while coming down
        v = v-1
         
        # object reached its maximum height
        if v<0:
             
            # negative sign is added to counter negative velocity
            m =-1
 
            # objected reaches line and stops
            if cara1_rect.colliderect(ctverec):
                isjump = False
                v = 7 - 1
                m = 1
                ctverec.bottom = cara1_rect.top + 1
            if cara2_rect.colliderect(ctverec):
                isjump = False
                v = 7 - 1
                m = 1
                ctverec.bottom = cara2_rect.top + 1

     
    # creates time delay of 10ms
    pygame.time.delay(50)
 
    # it refreshes the screendow
    pygame.display.update() 
# closes the pygame screendow    
pygame.quit()
